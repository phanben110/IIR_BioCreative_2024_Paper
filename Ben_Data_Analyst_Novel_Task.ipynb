# %%
import pandas as pd
import os
forder_train = "/content/drive/MyDrive/BioCreativeVIII/BioREx/datas/Bio_Competition_dataset/train"
list_file = os.listdir(forder_train)  
# Initialize data collection list
list_data_NER = []
list_data_RE = []
text_t_in_documents = {} 
text_a_in_documents = {}
for file_path in list_file: 
    file_path = os.path.join(forder_train, file_path)  
# Open and process the file
    with open(file_path, 'r') as file:

        for line in file:
            fields = line.strip().split('\t')
            if len(fields) == 6:
                list_data_NER.append([fields[0],fields[1], fields[2], fields[3], fields[4], fields[5]])
            elif len(fields) == 1 and '|t|' in fields[0]: 
                position_t = fields[0].find('|t|')
                id_document = fields[0][:position_t]
                text_t_in_documents.update({id_document :fields[0][position_t+3:]})
            elif len(fields) == 1 and '|a|' in fields[0]:
                position_a = fields[0].find('|a|')
                id_document = fields[0][:position_a] 
                text_a_in_documents.update({id_document :fields[0][position_a+3:]}) 
            elif len(fields) == 5: 
                list_data_RE.append([fields[0],fields[1], fields[2], fields[3], fields[4]])
    data_frame_RE = pd.DataFrame(list_data_RE, columns=["doc_id", "relation", "id_identifier_1", "id_identifier_2", "novel_cls"])       
    data_frame_NER = pd.DataFrame(list_data_NER, columns=["doc_id", "offset_1", "offset_2", "entity", "identifier", "id_identifier"])

# %%
text_in_documents={}
for key in text_t_in_documents.keys(): 
    full_text = text_t_in_documents[key] + " " + text_a_in_documents[key]
    text_in_documents.update({key:full_text}) 
data_frame_NER['full_document'] = data_frame_NER['doc_id'].map(text_in_documents)

# %%
data_frame_NER_work = data_frame_NER.copy()
data_frame_NER_work
# Out:
#                         doc_id offset_1 offset_2  \
# 0        BC8_BioRED_Task1_Doc0       51       55
# 1        BC8_BioRED_Task1_Doc0       60       79
# 2        BC8_BioRED_Task1_Doc0      113      138
# 3        BC8_BioRED_Task1_Doc0      140      144
# 4        BC8_BioRED_Task1_Doc0      244      309
# ...                        ...      ...      ...
# 16879  BC8_BioRED_Task1_Doc499     1843     1847
# 16880  BC8_BioRED_Task1_Doc499     1875     1885
# 16881  BC8_BioRED_Task1_Doc499     1919     1923
# 16882  BC8_BioRED_Task1_Doc499     1955     1957
# 16883  BC8_BioRED_Task1_Doc499     2129     2141
#
#                                                   entity       identifier  \
# 0                                                   MMP1             Gene
# 1                                    lumbar disc disease          Disease
# 2                              Matrix metalloproteinases             Gene
# 3                                                   MMPs             Gene
# 4      guanine insertion/deletion (G/D), the -1607 pr...  SequenceVariant
# ...                                                  ...              ...
# 16879                                               rats    OrganismTaxon
# 16880                                         superoxide         Chemical
# 16881                                               rats    OrganismTaxon
# 16882                                                 NO         Chemical
# 16883                                       hypertension          Disease
#
#        id_identifier                                      full_document
# 0               4312  Association between promoter -1607 polymorphis...
# 1            C535531  Association between promoter -1607 polymorphis...
# 2               4312  Association between promoter -1607 polymorphis...
# 3               4312  Association between promoter -1607 polymorphis...
# 4      c|DEL|-1607|G  Association between promoter -1607 polymorphis...
# ...              ...                                                ...
# 16879          10116  Mechanisms of hypertension induced by nitric o...
# 16880        D013481  Mechanisms of hypertension induced by nitric o...
# 16881          10116  Mechanisms of hypertension induced by nitric o...
# 16882        D009569  Mechanisms of hypertension induced by nitric o...
# 16883        D006973  Mechanisms of hypertension induced by nitric o...
#
# [16884 rows x 7 columns]

# %%
# Assuming df is your DataFrame
def extract_entity(row):
    return row['full_document'][int(row['offset_1']):int(row['offset_2'])]

data_frame_NER_work['entity1_offset'] = data_frame_NER_work.apply(extract_entity, axis=1)
data_frame_NER_work
# Out:
#                         doc_id offset_1 offset_2  \
# 0        BC8_BioRED_Task1_Doc0       51       55
# 1        BC8_BioRED_Task1_Doc0       60       79
# 2        BC8_BioRED_Task1_Doc0      113      138
# 3        BC8_BioRED_Task1_Doc0      140      144
# 4        BC8_BioRED_Task1_Doc0      244      309
# ...                        ...      ...      ...
# 16879  BC8_BioRED_Task1_Doc499     1843     1847
# 16880  BC8_BioRED_Task1_Doc499     1875     1885
# 16881  BC8_BioRED_Task1_Doc499     1919     1923
# 16882  BC8_BioRED_Task1_Doc499     1955     1957
# 16883  BC8_BioRED_Task1_Doc499     2129     2141
#
#                                                   entity       identifier  \
# 0                                                   MMP1             Gene
# 1                                    lumbar disc disease          Disease
# 2                              Matrix metalloproteinases             Gene
# 3                                                   MMPs             Gene
# 4      guanine insertion/deletion (G/D), the -1607 pr...  SequenceVariant
# ...                                                  ...              ...
# 16879                                               rats    OrganismTaxon
# 16880                                         superoxide         Chemical
# 16881                                               rats    OrganismTaxon
# 16882                                                 NO         Chemical
# 16883                                       hypertension          Disease
#
#        id_identifier                                      full_document  \
# 0               4312  Association between promoter -1607 polymorphis...
# 1            C535531  Association between promoter -1607 polymorphis...
# 2               4312  Association between promoter -1607 polymorphis...
# 3               4312  Association between promoter -1607 polymorphis...
# 4      c|DEL|-1607|G  Association between promoter -1607 polymorphis...
# ...              ...                                                ...
# 16879          10116  Mechanisms of hypertension induced by nitric o...
# 16880        D013481  Mechanisms of hypertension induced by nitric o...
# 16881          10116  Mechanisms of hypertension induced by nitric o...
# 16882        D009569  Mechanisms of hypertension induced by nitric o...
# 16883        D006973  Mechanisms of hypertension induced by nitric o...
#
#                                           entity1_offset
# 0                                                   MMP1
# 1                                    lumbar disc disease
# 2                              Matrix metalloproteinases
# 3                                                   MMPs
# 4      guanine insertion/deletion (G/D), the -1607 pr...
# ...                                                  ...
# 16879                                               rats
# 16880                                         superoxide
# 16881                                               rats
# 16882                                                 NO
# 16883                                       hypertension
#
# [16884 rows x 8 columns]

# %%
import pandas as pd

def extract_full_text(row):
    start_index = int(row['offset_1'])
    end_index = int(row['offset_2'])
    full_document = row['full_document']
    
    # Find the position of the first '.' after end_index
    end_period_index = full_document.find('.', end_index)
    
    # Find the position of the last '.' before start_index
    last_period_index = full_document.rfind('.', 0, start_index)
    
    if last_period_index != -1:
        return full_document[last_period_index + 1:end_period_index + 1]
    else:
        #return full_document[start_index:end_period_index + 1]
        return full_document[0:end_period_index + 1]

# Assuming df is your DataFrame
data_frame_NER_work['full_sentence'] = data_frame_NER_work.apply(extract_full_text, axis=1)

# Print the updated DataFrame
data_frame_NER_work["full_sentence"].iloc[1000]
# Out:
# ' Inhibition of Na(+) channels by local anesthetics may regulate desipramine-induced down-regulation of NET function.'

# %%
data_frame_NER_work["entity"].iloc[1000]
data_frame_NER_clean = data_frame_NER_work.drop(['offset_1', 'offset_2', "full_document", "entity1_offset"], axis=1)
data_frame_NER_clean
# Out:
#                         doc_id  \
# 0        BC8_BioRED_Task1_Doc0
# 1        BC8_BioRED_Task1_Doc0
# 2        BC8_BioRED_Task1_Doc0
# 3        BC8_BioRED_Task1_Doc0
# 4        BC8_BioRED_Task1_Doc0
# ...                        ...
# 16879  BC8_BioRED_Task1_Doc499
# 16880  BC8_BioRED_Task1_Doc499
# 16881  BC8_BioRED_Task1_Doc499
# 16882  BC8_BioRED_Task1_Doc499
# 16883  BC8_BioRED_Task1_Doc499
#
#                                                   entity       identifier  \
# 0                                                   MMP1             Gene
# 1                                    lumbar disc disease          Disease
# 2                              Matrix metalloproteinases             Gene
# 3                                                   MMPs             Gene
# 4      guanine insertion/deletion (G/D), the -1607 pr...  SequenceVariant
# ...                                                  ...              ...
# 16879                                               rats    OrganismTaxon
# 16880                                         superoxide         Chemical
# 16881                                               rats    OrganismTaxon
# 16882                                                 NO         Chemical
# 16883                                       hypertension          Disease
#
#        id_identifier                                      full_sentence
# 0               4312  Association between promoter -1607 polymorphis...
# 1            C535531  Association between promoter -1607 polymorphis...
# 2               4312   BACKGROUND: Matrix metalloproteinases (MMPs) ...
# 3               4312   BACKGROUND: Matrix metalloproteinases (MMPs) ...
# 4      c|DEL|-1607|G   A SNP for guanine insertion/deletion (G/D), t...
# ...              ...                                                ...
# 16879          10116   Carotid arteries, vena cava, and sympathetic ...
# 16880        D013481   Carotid arteries, vena cava, and sympathetic ...
# 16881          10116   Carotid arteries, vena cava, and sympathetic ...
# 16882        D009569   These data suggest that while NO deficiency i...
# 16883        D006973   These data suggest that while NO deficiency i...
#
# [16884 rows x 5 columns]

# %%
data_frame_NER_clean.drop_duplicates(subset=['entity', 'full_sentence', 'doc_id'], inplace=True)
data_frame_NER_clean
# Out:
#                         doc_id  \
# 0        BC8_BioRED_Task1_Doc0
# 1        BC8_BioRED_Task1_Doc0
# 2        BC8_BioRED_Task1_Doc0
# 3        BC8_BioRED_Task1_Doc0
# 4        BC8_BioRED_Task1_Doc0
# ...                        ...
# 16878  BC8_BioRED_Task1_Doc499
# 16879  BC8_BioRED_Task1_Doc499
# 16880  BC8_BioRED_Task1_Doc499
# 16882  BC8_BioRED_Task1_Doc499
# 16883  BC8_BioRED_Task1_Doc499
#
#                                                   entity       identifier  \
# 0                                                   MMP1             Gene
# 1                                    lumbar disc disease          Disease
# 2                              Matrix metalloproteinases             Gene
# 3                                                   MMPs             Gene
# 4      guanine insertion/deletion (G/D), the -1607 pr...  SequenceVariant
# ...                                                  ...              ...
# 16878                                               LNNA         Chemical
# 16879                                               rats    OrganismTaxon
# 16880                                         superoxide         Chemical
# 16882                                                 NO         Chemical
# 16883                                       hypertension          Disease
#
#        id_identifier                                      full_sentence
# 0               4312  Association between promoter -1607 polymorphis...
# 1            C535531  Association between promoter -1607 polymorphis...
# 2               4312   BACKGROUND: Matrix metalloproteinases (MMPs) ...
# 3               4312   BACKGROUND: Matrix metalloproteinases (MMPs) ...
# 4      c|DEL|-1607|G   A SNP for guanine insertion/deletion (G/D), t...
# ...              ...                                                ...
# 16878        D019335   Carotid arteries, vena cava, and sympathetic ...
# 16879          10116   Carotid arteries, vena cava, and sympathetic ...
# 16880        D013481   Carotid arteries, vena cava, and sympathetic ...
# 16882        D009569   These data suggest that while NO deficiency i...
# 16883        D006973   These data suggest that while NO deficiency i...
#
# [15908 rows x 5 columns]

# %%
data_frame_RE
# Out:
#                        doc_id              relation   id_identifier_1  \
# 0       BC8_BioRED_Task1_Doc0  Positive_Correlation     c|DEL|-1607|G
# 1       BC8_BioRED_Task1_Doc0           Association           D055959
# 2       BC8_BioRED_Task1_Doc0  Positive_Correlation  c|Allele|D|-1607
# 3       BC8_BioRED_Task1_Doc0           Association              4312
# 4       BC8_BioRED_Task1_Doc0           Association           C535531
# ...                       ...                   ...               ...
# 5335  BC8_BioRED_Task1_Doc499  Negative_Correlation           D019335
# 5336  BC8_BioRED_Task1_Doc499  Positive_Correlation           D019335
# 5337  BC8_BioRED_Task1_Doc499  Negative_Correlation           D009569
# 5338  BC8_BioRED_Task1_Doc499           Association           D006973
# 5339  BC8_BioRED_Task1_Doc499  Negative_Correlation           D006973
#
#      id_identifier_2 novel_cls
# 0            C535531     Novel
# 1      c|DEL|-1607|G     Novel
# 2            D055959     Novel
# 3            D055959     Novel
# 4               4312     Novel
# ...              ...       ...
# 5335           24323     Novel
# 5336         D006973        No
# 5337         D018754        No
# 5338           24323        No
# 5339         D009569        No
#
# [5340 rows x 5 columns]

# %%
# def extract_entity_from_NER_dataframe_1(doc_id, id_identifier): 
#     doc_id_data = data_frame_NER_clean[data_frame_NER_clean['doc_id'] == doc_id] 
#     doc_id_data_id_identifier = doc_id_data[doc_id_data['id_identifier'] == id_identifier] 
#     doc_id_data_id_identifier.drop(['doc_id','id_identifier'],axis=1, inplace=True) 
#     return doc_id_data_id_identifier.rename(columns={'entity': 'entity_1', 
#                                                      'id_identifier': 'id_identifier_1', 
#                                                      'full_sentence': 'full_sentence_1'
#                                                      }).iloc[0].values
def extract_entity_from_NER_dataframe(doc_id, id_identifier):
    doc_id_data = data_frame_NER_clean[data_frame_NER_clean['doc_id'] == doc_id]
    doc_id_data_id_identifier = doc_id_data[doc_id_data['id_identifier'] == id_identifier]
    
    if not doc_id_data_id_identifier.empty:
        # Check if the resulting DataFrame is not empty
        row = doc_id_data_id_identifier.iloc[0]
        return row['entity'], row['identifier'], row['full_sentence']
    else:
        # Return default values or handle the case when there's no matching row
        return None, None, None


# Gọi hàm extract_entity_from_NER_dataframe
entity, identifier, full_sentence = extract_entity_from_NER_dataframe("BC8_BioRED_Task1_Doc3", "C563856")

entity, identifier, full_sentence
# Out:
# ('sudden infant death with dysgenesis of the testes syndrome',
#  'Disease',
#  ' Recently, a lethal phenotype characterized by sudden infant death with dysgenesis of the testes syndrome (SIDDT) was identified to be caused by loss of function mutations in the TSPYL1 gene.')

# %%
import pandas as pd

# Assuming your DataFrame is named data_frame_RE

def add_entity_info_to_dataframe_1(row):
    doc_id = row['doc_id']
    id_identifier = row['id_identifier_1']
    
    entity, identifier, full_sentence = extract_entity_from_NER_dataframe(doc_id, id_identifier)
    
    return pd.Series({'entity_1': entity, 'identifier_1': identifier, 'full_sentence_1': full_sentence})

# Apply the function to each row of data_frame_RE
new_columns = data_frame_RE.apply(add_entity_info_to_dataframe_1, axis=1)

# Concatenate the new columns to data_frame_RE
data_frame_RE_merge_1 = pd.concat([data_frame_RE, new_columns], axis=1)

# %%
def add_entity_info_to_dataframe_2(row):
    doc_id = row['doc_id']
    id_identifier = row['id_identifier_2']
    
    entity, identifier, full_sentence = extract_entity_from_NER_dataframe(doc_id, id_identifier)
    
    return pd.Series({'entity_2': entity, 'identifier_2': identifier, 'full_sentence_2': full_sentence})

# Apply the function to each row of data_frame_RE
new_columns = data_frame_RE_merge_1.apply(add_entity_info_to_dataframe_2, axis=1)

# Concatenate the new columns to data_frame_RE
data_frame_RE_merge_2 = pd.concat([data_frame_RE_merge_1, new_columns], axis=1)

# %%
data_frame_RE_merge_2.to_csv('dataset_train_novel/train_novel.csv')

# %%
data_frame_RE_merge_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-881c24ad8727> in <cell line: 1>()
# ----> 1 data_frame_RE_merge_2
#
# NameError: name 'data_frame_RE_merge_2' is not defined

# %%
data_frame_NER['identifier'].value_counts()
# Out:
# Gene               5517
# Disease            4628
# Chemical           3675
# OrganismTaxon      1799
# SequenceVariant    1140
# CellLine            125
# Name: identifier, dtype: int64

# %%
data_frame_RE['novel_cls'].value_counts()
# Out:
# Novel    3678
# No       1667
# Name: novel_cls, dtype: int64

# %%
data_frame_RE['relation'].value_counts()
# Out:
# Association             2757
# Positive_Correlation    1441
# Negative_Correlation     979
# Bind                      80
# Cotreatment               41
# Comparison                33
# Drug_Interaction          11
# Conversion                 3
# Name: relation, dtype: int64
